# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 3
#
# ## О документе
#
# Версия 1.03
#
# Модуль 3 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 3. Внедрение блоков функциональной и информационной безопасности
# #### Общая идея
#
# Ключевая идея кибериммунной автономности заключается в том, чтобы уже на этапе проектирования внедрить защиту от кибератак как снаружи, так и изнутри - т.е. через уязвимые бортовые информационные системы.
# Мы исходим из того, что абсолютно защищённых систем не бывает, чем больше и сложнее код, тем проще одним ("плохим") в нём спрятать уязвимости, а другим ("хорошим", но уставшим) эти уязвимости не найти.
#
# Поэтому необходимо сделать так, чтобы наиболее критичный код был отделён от некритичного и протестирован особенно тщательно - таким образом можно снизить вероятность успешной атаки и затруднить задачу атакующим.

# %% [markdown]
# #### Цели и предположения безопасности
#
# ##### Цели безопасности
# Устойчивость кибериммунных систем к атакам выражается в том, что поставленные заказчиком **цели безопасности** (ЦБ) не нарушаются даже в условиях кибератак (снаружи и изнутри).
#
# Для наших автономных машинок заказчиком поставлены следующие ЦБ:
#
# 1. При любых обстоятельствах АНТС осуществляет перемещения в пределах заданных ограничений
#
# 2. При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут
#
# 3. При любых обстоятельствах АНТС оставляет груз только в авторизованном пункте назначения
#
# Ниже используется цифро-буквенное обозначение целей безопасности - например, ЦБ1 - первая цель безопасности из списка выше.
#
# ##### Предположения безопасности
# При этом заказчик согласовал с разработчиками следующие **предположения безопасности** (ПБ) - утверждения о смежных системах, которые снимают с разработчиков часть задач для обеспечения целей безопасности:
#
# 1. При любых обстоятельствах только авторизованный персонал имеет физический доступ к критическим узлам АНТС
#
# 2. При любых обстоятельствах только аутентичные и авторизованные операторы имеют доступ к системе планирования заданий
#
# 3. Аутентичные и авторизованные операторы обладают необходимой квалификацией и являются благонадёжными (т.е. не пытаются намеренно причинить ущерб системе или третьим лицам, используя доступ к АНТС)
#
# Ниже используется цифро-буквенное обозначение предположений безопасности - например, ПБ1 - первое предположение безопасности из списка выше.

# %% [markdown]
# ### Киберпрепятствия
#
# Прежде чем мы начнём внедрять механизмы безопасности, посмотрим, что произойдёт с нашей машинкой, если бортовые системы начнут вести себя не так, как мы ожидаем.
#
# Для этого активируем специальный режим работы системы управления и снова запустим машинку по тому же маршруту, который был в конце модуля 2.
#
# После инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# Но вначале нужно из модуля 2 скопировать сюда ваши текущие наработки, а именно ваши реализации классов коммуникационного шлюза (CommunicationGateway), систему навигации (NavigationSystem), управления (ControlSystem), также будем использовать маршрут, который вы создали.

# %%
# вставьте сюда ваш код

from multiprocessing import Queue
from src.event_types import Event
from src.communication_gateway import BaseCommunicationGateway
from src.navigation_system import BaseNavigationSystem
from src.control_system import BaseControlSystem
from src.config import CONTROL_SYSTEM_QUEUE_NAME, CARGO_BAY_QUEUE_NAME, SERVOS_QUEUE_NAME


class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        
        # имена очередей блоков находятся в файле src/config.py
        # события нужно отправлять в соответствие с диаграммой информационных потоков
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME

        # события передаются в виде экземпляров класса Event, 
        # описание класса находится в файле src/event_types.py
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )

        # поиск в каталоге нужной очереди (в данном случае - системы управления)
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        # отправка события в найденную очередь
        control_q.put(event)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди
        event = Event(source=self.event_source_name,
                            destination=control_q_name,
                            operation="position_update",
                            parameters=self._position) # замените на код создания сообщения с координатами для системы управления 
                     # подсказка, требуемая операция - position_update
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
    

class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # инициализация сообщения с желаемой скоростью
        # подсказка: блок Приводы ожидает команду "set_speed" с параметром в виде скорости
        event_speed = Event(
            source=self.event_source_name,
            destination=servos_q_name,
            operation="set_speed",
            parameters=speed
        ) # <-- измените эту строку!

        # отправка сообщения с желаемым направлением
        # подсказка: блок Приводы ожидает команду "set_direction" с параметром в виде направления
        event_direction = Event(
            source=self.event_source_name,
            destination=servos_q_name,
            operation="set_direction",
            parameters=direction
        ) # <-- измените эту строку!

        servos_q.put(event_speed)
        servos_q.put(event_direction)

    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        # инициализация сообщения с командой на блокировку грузового отсека
        # подсказка: блок CargoBay ожидает команду "lock_cargo" без параметров
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        ) # <-- измените эту строку!
        cargo_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        # инициализация сообщения с командой на блокировку грузового отсека
        # подсказка: блок CargoBay ожидает команду "release_cargo" без параметров
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        ) # <-- измените эту строку!

        cargo_q.put(event)

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m3"

# %%
# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint


from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser


# возьмём маршрут из модуля 2
wpl_file = "module2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 30),
    GeoSpecificSpeedLimit(1, 60),
    GeoSpecificSpeedLimit(5, 20),
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

# по аналогии собираем все блоки в одном кузове
system_components = SystemComponentsContainer(
    components=[
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system
    ] if afcs_present else [
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

system_components.start()

# ограничение поездки по времени
# параметр sleep - время в секундах,
# настройте этот параметр так, чтобы ваша машинка завершила маршрут
# в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# при условии, что повторный запуск закончился успешно
sleep(5)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
del system_components
# Out:
# [Point(59.932206, 30.336413, 0.0), Point(59.932347, 30.336474, 0.0), Point(59.932241, 30.33723, 0.0), Point(59.933763, 30.337978, 0.0), Point(59.933839, 30.337488, 0.0), Point(59.934066, 30.337595, 0.0), Point(59.934129, 30.337156, 0.0), Point(59.934238, 30.33723, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 17:55:28.678645
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][CONTROL] новая скорость 30 (была 0)
# [ИНФО][CONTROL] новое направление 12 (было 0)
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 30)
# [ИНФО][CONTROL] новое направление 279 (было 12)
# [ИНФО][CONTROL] новое направление 280 (было 279)
# [ИНФО][CONTROL] новое направление 282 (было 280)
# [ИНФО][CONTROL] новое направление 281 (было 282)

# %% [markdown]
# Итак, в отличие от, надеемся, успешного завершения маршрута в модуле 2, сейчас ваша машинка ведёт себя совсем иначе. Например, она внезапно едет в совершенно другую сторону (это особенно хорошо видно при использовании СУПА).
# И это ещё не всё, что может пойти не так..
#
# В этой реализации не очень много кода, теоретически, вы можете его весь изучить и устранить "незадокументированные возможности", однако в реальных системах кода гораздо больше. Например, кодовая база проекта с открытым исходным кодом ArduPilot, реализующего в том числе логику автопилота, составляет примерно миллион строк.
#
# Сколько времени вам понадобится, чтобы изучить и протестировать миллион строк кода? А ведь придётся проводить анализ и каждого обновления.. При этом неприятности могут быть хорошо спрятанными и на первый взгляд безобидными, вряд ли злоумышленники облегчат задачу и назовут свои изменения, например, "hacking_the_system" или "allowing_secret_remote_access". Вредоносный код может выглядеть совершенно безобидно или маскироваться под программный дефект.
#
# Поэтому тщательный анализ потребует большого количества ресурсов (человеческих, вычислительных, временныз), что стоит дорого.
#
# Логичным выходом является выделение критичных для целей безопасности проверок в отдельный блок, который протестировать должно быть гораздо проще.

# %% [markdown]
# #### Задания
#
# В этом модуле задание будет состоять из двух частей разной сложности:
#
# **3.1. добавить новый блок - "Ограничитель"** - этот модуль должен будет обеспечить соблюдение ограничений, указанных в маршрутном задании - это необходимо для обеспечения ЦБ1
#
# **З.2. *(задание повышенной сложности)* добавить монитор безопасности (МБ)** - он должен контролировать все взаимодействия *бортовых систем* (т.е. не включая планировщик и симулятор) и не давать блокам взаимодействовать друг с другом непредусмотренным образом - например, блок №5 может принимать команды только от №3, попытка передать команду в №5 от №2 должна блокироваться нашим монитором безопасности - потенциально это необходимо для обеспечения всех ЦБ

# %% [markdown]
# Для выполнения первой части задачи 3.1. необходимо для начала изменить архитектуру АНТС как показано на рис. 5
#
# ![Архитектура системы с ограничителем](images/ciac-arch-m31.png)
#
# Рис. 5. Архитектура АНТС с ограничителем (для ЦБ1)

# %% [markdown]
# Код базового класса Ограничителя находится в файле src/safety_block.py
#
# По аналогии с заданием в модуле 1, необходимо создать на основе этого класса свой собственный под названием SafetyBlock, в котором реализовать передачу команд в приводы движения, только перед эти необходимо ещё и проконтролировать их безопасность.
#
# Также необходимо реализовать передачу маршрутного задания из CommunicationGateway в SafetyBlock и координат из модуля Navigation в соответствии со стрелками на рис.5 выше.
#
# Если всё сделано правильно, то Ограничителю будет известно следующее
#
# - _mission - текущее маршрутное задание
# - _position - текущие координаты
#
# После проверки нужно установить значение внутренних переменных
# - _speed - текущая (допустимая) скорость
# - _direction - текущее (допустимое) направление
#
# Желательно завершить следование по маршруту. В критической ситуации, если продолжение маршрута невозможно, следует установить значение скорости и направления в 0, после чего передать эти команды в блок приводов (Servos)

# %% [markdown]
# Базовый сценарий для новой архитектуры можно представить следующим образом (см. рис. 6)
#
# ![Базовый сценарий с блоком безопасности](images/basic-scenario-with-safety-block1.png)
#
# Рис. 6. Базовый сценарий с блоком безопасности

# %% [markdown]
# Заготовка кода SafetyBlock
#
# ```python
# class SafetyBlock(BaseSafetyBlock):
#     """ класс ограничений безопасности """
#
#     def _set_new_direction(self, direction: float):
#         """ установка нового направления перемещения """
#         self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
#         self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
#         self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
#         # TODO реализовать контроль безопасности изменения направления
#         self._direction = direction
#         self._send_direction_to_consumers()
#
#     def _set_new_speed(self, speed: float):
#         """ установка новой скорости """
#         # TODO реализовать контроль безопасности изменения скорости
#         self._speed = speed
#         self._send_speed_to_consumers()
#
#
#     def _send_speed_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем скорость получателям")
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_speed",
#                             parameters=self._speed
#                             )
#         servos_q.put(event_speed)
#
#     def _send_direction_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем направление получателям")
#
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_direction",
#                             parameters=self._direction
#                             )
#         servos_q.put(event_speed)
# ```

# %%
# 1. скопируйте сюда код заготовки из предыдущей ячейки и напишите свою реализацию класса SafetyBlock

from src.safety_block import BaseSafetyBlock
from src.config import LOG_DEBUG, LOG_INFO, LOG_ERROR, DEFAULT_LOG_LEVEL
from src.control_system import BaseControlSystem

class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    # def __init__(self, queues_dir: QueuesDirectory, log_level = DEFAULT_LOG_LEVEL):
    #     super().__init__(queues_dir, log_level)
    #     self._tolerance_meters = 1
    #     self._recalc_interval_sec = 0.1

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления    
        if not self._position:
            self._log_message(LOG_ERROR, "неизвестны текущие координаты. Разворот в стандартное положение.")
            self._direction = 0;
        elif not self._mission:
            self._log_message(LOG_ERROR, "отсутствует заданный маршрут. Разворот в стандартное положение.")
            self._direction = 0;
        else:
            pos = self._position
            dst = self._route.next_point();
            # self._log_message(LOG_DEBUG, f"{pos}\n, {dst}\n, {self._route.current_index}\n, {self._route.calculate_remaining_distance_to_next_point(self._position)}")
            assumed_direction = BaseControlSystem._calculate_bearing(None, pos, dst)

            if direction != assumed_direction:
                self._log_message(LOG_ERROR, f"произошло отклонение от маршрута. Произведена корректировка {direction} на {assumed_direction}.")
            self._direction = assumed_direction

        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        # TODO реализовать контроль безопасности изменения скорости
        if not self._position:
            self._log_message(LOG_ERROR, "неизвестны текущие координаты. Остановка.")
            self._speed = 0;
        elif not self._mission:
            self._log_message(LOG_ERROR, "отсутствует заданный маршрут. Остановка.")
            self._speed = 0;
        else:
            allowed_speed = self._route.calculate_speed()
            if (speed > allowed_speed):
                self._log_message(LOG_ERROR, f"превышен лимит скорости на текущем участке. ({speed}/{allowed_speed}). Ограничиваем до {allowed_speed}")
                self._speed = allowed_speed
            else:
                self._speed = speed
        self._send_speed_to_consumers()


    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)

# %%
# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

from multiprocessing import Queue
from src.event_types import Event
from src.communication_gateway import BaseCommunicationGateway
from src.navigation_system import BaseNavigationSystem
from src.control_system import BaseControlSystem
from src.config import CONTROL_SYSTEM_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME


class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        
        # имена очередей блоков находятся в файле src/config.py
        # события нужно отправлять в соответствие с диаграммой информационных потоков
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # события передаются в виде экземпляров класса Event, 
        # описание класса находится в файле src/event_types.py
        control_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                             destination=safety_q_name,
                             operation="set_mission", parameters=self._mission)

        # поиск в каталоге нужной очереди (в данном случае - системы управления)
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        # отправка события в найденную очередь
        control_q.put(control_event)
        safety_q.put(safety_event)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        control_event = Event(source=self.event_source_name,
                              destination=control_q_name,
                              operation="position_update",
                              parameters=self._position)
        safety_event = Event(source=self.event_source_name,
                             destination=safety_q_name,
                             operation="position_update",
                             parameters=self._position)
        
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        control_q.put(control_event)
        safety_q.put(safety_event)
    

class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # инициализация сообщения с желаемой скоростью
        # подсказка: блок Приводы ожидает команду "set_speed" с параметром в виде скорости
        event_speed = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="set_speed",
            parameters=speed
        ) # <-- измените эту строку!

        # отправка сообщения с желаемым направлением
        # подсказка: блок Приводы ожидает команду "set_direction" с параметром в виде направления
        event_direction = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="set_direction",
            parameters=direction
        ) # <-- измените эту строку!

        safety_q.put(event_speed)
        safety_q.put(event_direction)

    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        safety_q = self._queues_dir.get_queue(safety_q_name)
        # инициализация сообщения с командой на блокировку грузового отсека
        # подсказка: блок CargoBay ожидает команду "lock_cargo" без параметров
        event = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="lock_cargo",
            parameters=None
        ) # <-- измените эту строку!
        safety_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        safety_q = self._queues_dir.get_queue(safety_q_name)
        # инициализация сообщения с командой на блокировку грузового отсека
        # подсказка: блок CargoBay ожидает команду "release_cargo" без параметров
        event = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="release_cargo",
            parameters=None
        ) # <-- измените эту строку!

        safety_q.put(event)

# 3. создайте экземпляры изменённых классов и отправьте машинку по ранее предложенному маршруту

queues_dir = QueuesDirectory() 

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)
# Out:
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation

# %%
# создадим все остальные компоненты

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)
# Out:
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель

# %%
# соберём все компоненты для запуска

# в зависимости от наличия СУПА используем разный набор компонентов - с передачей телеметрии или без

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(30)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 17:55:34.751531
# [ИНФО][CONTROL] новая скорость 30 (была 0)
# [ИНФО][CONTROL] новое направление 12 (было 0)
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9416s N, 30 20m 11.0868s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9416s N, 30 20m 11.0868s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9416s N, 30 20m 11.0868s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9416s N, 30 20m 11.0868s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9679s N, 30 20m 11.0982s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9942s N, 30 20m 11.1095s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0205s N, 30 20m 11.1209s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0469s N, 30 20m 11.1323s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0732s N, 30 20m 11.1436s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0995s N, 30 20m 11.155s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1258s N, 30 20m 11.1664s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1521s N, 30 20m 11.1777s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1784s N, 30 20m 11.1891s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2048s N, 30 20m 11.2005s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2311s N, 30 20m 11.2119s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2574s N, 30 20m 11.2232s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2837s N, 30 20m 11.2346s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 30)
# [ИНФО][CONTROL] новое направление 99 (было 12)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.31s N, 30 20m 11.246s E
# [ИНФО][CONTROL] новое направление 100 (было 99)
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3363s N, 30 20m 11.2574s E
# [ИНФО][CONTROL] новое направление 102 (было 100)
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3626s N, 30 20m 11.2688s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3534s N, 30 20m 11.3745s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3432s N, 30 20m 11.4799s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3319s N, 30 20m 11.5848s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3206s N, 30 20m 11.6897s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3093s N, 30 20m 11.7946s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2979s N, 30 20m 11.8995s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2865s N, 30 20m 12.0044s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2752s N, 30 20m 12.1093s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2638s N, 30 20m 12.2142s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2524s N, 30 20m 12.3191s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2411s N, 30 20m 12.424s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2297s N, 30 20m 12.5288s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2183s N, 30 20m 12.6337s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.207s N, 30 20m 12.7386s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1956s N, 30 20m 12.8435s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1842s N, 30 20m 12.9484s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1729s N, 30 20m 13.0533s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1615s N, 30 20m 13.1582s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1502s N, 30 20m 13.2631s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1388s N, 30 20m 13.368s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1388s N, 30 20m 13.368s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1275s N, 30 20m 13.4729s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1161s N, 30 20m 13.5778s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1048s N, 30 20m 13.6827s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 15 (было 102)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0934s N, 30 20m 13.7876s E
# [ИНФО][CONTROL] новое направление 13 (было 15)
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0708s N, 30 20m 13.9974s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0708s N, 30 20m 13.9974s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0594s N, 30 20m 14.1023s E
# [ИНФО][CONTROL] новое направление 12 (было 13)
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0481s N, 30 20m 14.2072s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1001s N, 30 20m 14.2351s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1524s N, 30 20m 14.2611s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2046s N, 30 20m 14.287s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.257s N, 30 20m 14.312s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3095s N, 30 20m 14.3359s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.362s N, 30 20m 14.3599s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.4145s N, 30 20m 14.3837s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.467s N, 30 20m 14.4076s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.5195s N, 30 20m 14.4315s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.572s N, 30 20m 14.4554s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.6245s N, 30 20m 14.4792s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.677s N, 30 20m 14.5031s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.7295s N, 30 20m 14.527s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.7821s N, 30 20m 14.5508s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.8346s N, 30 20m 14.5747s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.8871s N, 30 20m 14.5986s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.9396s N, 30 20m 14.6224s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.9921s N, 30 20m 14.6463s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.0446s N, 30 20m 14.6702s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.0971s N, 30 20m 14.6941s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.1496s N, 30 20m 14.7179s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.2021s N, 30 20m 14.7418s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.2546s N, 30 20m 14.7657s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.3071s N, 30 20m 14.7895s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.3596s N, 30 20m 14.8134s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.4121s N, 30 20m 14.8373s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.4646s N, 30 20m 14.8612s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.5171s N, 30 20m 14.885s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.5696s N, 30 20m 14.9089s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.6221s N, 30 20m 14.9328s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.6746s N, 30 20m 14.9567s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.7271s N, 30 20m 14.9805s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.7796s N, 30 20m 15.0044s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.8321s N, 30 20m 15.0283s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.8847s N, 30 20m 15.0522s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.9372s N, 30 20m 15.0761s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.9897s N, 30 20m 15.0999s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.0422s N, 30 20m 15.1238s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.0947s N, 30 20m 15.1477s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.1472s N, 30 20m 15.1716s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.1997s N, 30 20m 15.1955s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.2522s N, 30 20m 15.2193s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.3047s N, 30 20m 15.2432s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.3572s N, 30 20m 15.2671s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.4097s N, 30 20m 15.291s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.4622s N, 30 20m 15.3149s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.5147s N, 30 20m 15.3388s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.5672s N, 30 20m 15.3627s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.6197s N, 30 20m 15.3865s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.6722s N, 30 20m 15.4104s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.7247s N, 30 20m 15.4343s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.7772s N, 30 20m 15.4582s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.8297s N, 30 20m 15.4821s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.8822s N, 30 20m 15.506s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.9347s N, 30 20m 15.5299s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.9872s N, 30 20m 15.5538s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.0397s N, 30 20m 15.5777s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.0922s N, 30 20m 15.6016s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.1447s N, 30 20m 15.6255s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.1972s N, 30 20m 15.6494s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.2497s N, 30 20m 15.6733s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.3022s N, 30 20m 15.6972s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.3547s N, 30 20m 15.7211s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.4072s N, 30 20m 15.745s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.4597s N, 30 20m 15.7689s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.5122s N, 30 20m 15.7928s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.5648s N, 30 20m 15.8167s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.6173s N, 30 20m 15.8406s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.6698s N, 30 20m 15.8645s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.7223s N, 30 20m 15.8884s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.7748s N, 30 20m 15.9123s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.8273s N, 30 20m 15.9362s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.8798s N, 30 20m 15.9601s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.9323s N, 30 20m 15.984s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.9848s N, 30 20m 16.0079s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.037258s N, 30 20m 16.0318s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.0897581s N, 30 20m 16.0558s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.142258s N, 30 20m 16.0797s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.194758s N, 30 20m 16.1036s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.247257s N, 30 20m 16.1275s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.299757s N, 30 20m 16.1514s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.352256s N, 30 20m 16.1754s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.404756s N, 30 20m 16.1993s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.457255s N, 30 20m 16.2232s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.509754s N, 30 20m 16.2471s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.562252s N, 30 20m 16.2711s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.614751s N, 30 20m 16.295s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.667249s N, 30 20m 16.3189s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.719747s N, 30 20m 16.3429s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.772244s N, 30 20m 16.3668s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.824742s N, 30 20m 16.3907s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.877239s N, 30 20m 16.4147s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.929735s N, 30 20m 16.4386s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.982232s N, 30 20m 16.4626s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.03473s N, 30 20m 16.4865s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.08722s N, 30 20m 16.5105s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.13972s N, 30 20m 16.5344s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.19221s N, 30 20m 16.5584s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.24471s N, 30 20m 16.5824s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.2972s N, 30 20m 16.6064s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.34969s N, 30 20m 16.6303s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 296 (было 12)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.40218s N, 30 20m 16.6543s E
# [ИНФО][CONTROL] новое направление 292 (было 296)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.45467s N, 30 20m 16.6783s E
# [ИНФО][CONTROL] новое направление 289 (было 292)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.50716s N, 30 20m 16.7024s E
# [ИНФО][CONTROL] новое направление 286 (было 289)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.55965s N, 30 20m 16.7264s E
# [ИНФО][CONTROL] новое направление 285 (было 286)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.58341s N, 30 20m 16.6301s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.60444s N, 30 20m 16.5313s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.6226s N, 30 20m 16.4303s E
# [ИНФО][CONTROL] новое направление 284 (было 285)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.63779s N, 30 20m 16.3273s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.65244s N, 30 20m 16.2241s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.66666s N, 30 20m 16.1206s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.68088s N, 30 20m 16.0171s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.69482s N, 30 20m 15.9134s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.70866s N, 30 20m 15.8097s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.72244s N, 30 20m 15.706s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.73617s N, 30 20m 15.6022s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.74985s N, 30 20m 15.4984s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.7635s N, 30 20m 15.3946s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.77712s N, 30 20m 15.2908s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 5 (было 284)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.79073s N, 30 20m 15.1869s E
# [ИНФО][CONTROL] новое направление 8 (было 5)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.8043s N, 30 20m 15.0831s E
# [ИНФО][CONTROL] новое направление 12 (было 8)
# [ИНФО][CONTROL] новое направление 16 (было 12)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.83138s N, 30 20m 14.8754s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 12.501030575409459 на 16.171161431883434.
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.83138s N, 30 20m 14.8754s E
# [ИНФО][CONTROL] новое направление 19 (было 16)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.84486s N, 30 20m 14.7715s E
# [ИНФО][CONTROL] новое направление 20 (было 19)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.89849s N, 30 20m 14.7813s E
# [ИНФО][CONTROL] новое направление 21 (было 20)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.95171s N, 30 20m 14.7978s E
# [ИНФО][CONTROL] новое направление 22 (было 21)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.00343s N, 30 20m 14.8277s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.05409s N, 30 20m 14.8641s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.10443s N, 30 20m 14.9022s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.15448s N, 30 20m 14.9418s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.20437s N, 30 20m 14.9822s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.25419s N, 30 20m 15.023s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.30396s N, 30 20m 15.0639s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.35371s N, 30 20m 15.1051s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.40343s N, 30 20m 15.1463s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.45314s N, 30 20m 15.1876s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 60)
# [ИНФО][CONTROL] новое направление 296 (было 22)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.50283s N, 30 20m 15.2289s E
# [ИНФО][CONTROL] новое направление 292 (было 296)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.55252s N, 30 20m 15.2703s E
# [ИНФО][CONTROL] новое направление 288 (было 292)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.6022s N, 30 20m 15.3118s E
# [ИНФО][CONTROL] новое направление 284 (было 288)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.65186s N, 30 20m 15.3533s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.65978s N, 30 20m 15.3212s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.66663s N, 30 20m 15.2881s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.67237s N, 30 20m 15.2542s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.67812s N, 30 20m 15.2203s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.68274s N, 30 20m 15.1858s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.68729s N, 30 20m 15.1512s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.69178s N, 30 20m 15.1165s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.69625s N, 30 20m 15.0819s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.70068s N, 30 20m 15.0472s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.70511s N, 30 20m 15.0126s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.70954s N, 30 20m 14.9779s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.71396s N, 30 20m 14.9432s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.71838s N, 30 20m 14.9086s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.72281s N, 30 20m 14.8739s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.72723s N, 30 20m 14.8392s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.73165s N, 30 20m 14.8045s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.73607s N, 30 20m 14.7699s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.74049s N, 30 20m 14.7352s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.74491s N, 30 20m 14.7005s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.74933s N, 30 20m 14.6659s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.75375s N, 30 20m 14.6312s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.75817s N, 30 20m 14.5965s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.76259s N, 30 20m 14.5619s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.76701s N, 30 20m 14.5272s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.77143s N, 30 20m 14.4925s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.77585s N, 30 20m 14.4579s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.78027s N, 30 20m 14.4232s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.78468s N, 30 20m 14.3885s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.7891s N, 30 20m 14.3538s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.79352s N, 30 20m 14.3192s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.79794s N, 30 20m 14.2845s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.80235s N, 30 20m 14.2498s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.80677s N, 30 20m 14.2152s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.81118s N, 30 20m 14.1805s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.8156s N, 30 20m 14.1458s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.82001s N, 30 20m 14.1111s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.82443s N, 30 20m 14.0765s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 359 (было 284)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.82884s N, 30 20m 14.0418s E
# [ИНФО][CONTROL] новое направление 1 (было 359)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.83325s N, 30 20m 14.0071s E
# [ИНФО][CONTROL] новое направление 3 (было 1)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.83766s N, 30 20m 13.9724s E
# [ИНФО][CONTROL] новое направление 6 (было 3)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.84207s N, 30 20m 13.9378s E
# [ИНФО][CONTROL] новое направление 8 (было 6)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.84648s N, 30 20m 13.9031s E
# [ИНФО][CONTROL] новое направление 9 (было 8)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.86443s N, 30 20m 13.9025s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.88238s N, 30 20m 13.9034s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.90029s N, 30 20m 13.9058s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.91814s N, 30 20m 13.9096s E
# [ИНФО][CONTROL] новое направление 10 (было 9)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.93588s N, 30 20m 13.915s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.95361s N, 30 20m 13.9207s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.97132s N, 30 20m 13.9266s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.98901s N, 30 20m 13.9326s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.00669s N, 30 20m 13.9388s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.02437s N, 30 20m 13.945s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.04205s N, 30 20m 13.9513s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.05972s N, 30 20m 13.9575s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.07739s N, 30 20m 13.9638s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.09506s N, 30 20m 13.9701s E
# [ИНФО][CONTROL] маршрут пройден, текущее время 17:55:59.612744
# [ИНФО][CONTROL] новая скорость 0.0 (была 20)
# [ИНФО][CONTROL] новое направление 0 (было 10)
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.11273s N, 30 20m 13.9764s E
# [ОШИБКА][SAFETY] ошибка обработки команд: 'NoneType' object has no attribute 'longitude'
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# #### Обеспечение ЦБ3: контроль доставки груза
#
# С помощью логики ограничителя выше мы реализовали обеспечение ЦБ1 (соблюдение заданных ограничений), однако есть ещё ЦБ3 (отгрузка только в заданной точке), не говоря о ЦБ2 (следование только по аутентичному маршруту).
#
# Для обеспечения ЦБ3 необходимо сделать следующее
# 1. изменить последовательность передачи команд, чтобы в блок управления грузовым отсеком (CargoBay) команды приходили только после проверки в Ограничителе
# 2. доработайте реализацию Ограничителя, чтобы команда на выгрузку передавалась в CargoBay только в конечной точке маршрута
# 3. продумайте логику работы блока безопасности, если система управления полностью перестанет работать (т.е. перестанет отправлять новые команды).
#
# Изменённая архитектура приведена на рис. 7.
#
# ![Ограничитель для обеспечения ЦБ1 и ЦБ3](images/ciac-arch-m312.png)
#
# Рис. 7. Ограничитель для обеспечения ЦБ1 и ЦБ3

# %%
# напишите свой код в этой ячейке, запустите машинку по маршруту, убедитесь, 
# что в конечной (и только в конечной!) точке CargoBay получает команду и успешно выполняет выгрузку

from src.safety_block import BaseSafetyBlock
from src.config import LOG_DEBUG, LOG_INFO, LOG_ERROR, DEFAULT_LOG_LEVEL
from src.control_system import BaseControlSystem

class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления    
        if not self._position:
            self._log_message(LOG_ERROR, "неизвестны текущие координаты. Разворот в стандартное положение.")
            self._direction = 0;
        elif not self._mission:
            self._log_message(LOG_ERROR, "отсутствует заданный маршрут. Разворот в стандартное положение.")
            self._direction = 0;
        else:
            pos = self._position
            dst = self._route.next_point();
            # self._log_message(LOG_DEBUG, f"{pos}\n, {dst}\n, {self._route.current_index}\n, {self._route.calculate_remaining_distance_to_next_point(self._position)}")
            assumed_direction = BaseControlSystem._calculate_bearing(None, pos, dst)

            if direction != assumed_direction:
                self._log_message(LOG_ERROR, f"произошло отклонение от маршрута. Произведена корректировка {direction} на {assumed_direction}.")
            self._direction = assumed_direction

        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        # TODO реализовать контроль безопасности изменения скорости
        if not self._position:
            self._log_message(LOG_ERROR, "неизвестны текущие координаты. Остановка.")
            self._speed = 0;
        elif not self._mission:
            self._log_message(LOG_ERROR, "отсутствует заданный маршрут. Остановка.")
            self._speed = 0;
        else:
            allowed_speed = self._route.calculate_speed()
            if (speed > allowed_speed):
                self._log_message(LOG_ERROR, f"превышен лимит скорости на текущем участке. ({speed}/{allowed_speed}). Ограничиваем до {allowed_speed}")
                self._speed = allowed_speed
            else:
                self._speed = speed
        self._send_speed_to_consumers()


    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_direction = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_direction)

    def _lock_cargo(self, _):
        self._log_message(LOG_DEBUG, "блокировка грузового отсека")
        self._send_lock_cargo_to_consumers();
        
    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем команду блокировки грузового отсека получателям")

        cargo_q_name = CARGO_BAY_QUEUE_NAME
        cargo_q: Queue = self._queues_dir.get_queue(cargo_q_name)

        # отправка сообщения с желаемой скоростью
        event_lock_cargo = Event(source=self.event_source_name,
                            destination=cargo_q_name,
                            operation="lock_cargo",
                            parameters=None
                            )
        cargo_q.put(event_lock_cargo)

    def _release_cargo(self, _):
        if not self._route:
            self._log_message(LOG_ERROR, "ошибка открытия грузового отсека. Отсутствует маршрут.")
            return
        if not self._route.route_finished:
            self._log_message(LOG_ERROR, "ошибка открытия грузового отсека. Не достигнута кончная точка маршрута.")
            return
        self._send_release_cargo_to_consumers()
            
    
    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем команду разблокировки грузового отсека получателям")

        cargo_q_name = CARGO_BAY_QUEUE_NAME
        cargo_q: Queue = self._queues_dir.get_queue(cargo_q_name)

        # отправка сообщения с желаемой скоростью
        event_release_cargo = Event(source=self.event_source_name,
                            destination=cargo_q_name,
                            operation="release_cargo",
                            parameters=None
                            )
        cargo_q.put(event_release_cargo)

# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

from multiprocessing import Queue
from src.event_types import Event
from src.communication_gateway import BaseCommunicationGateway
from src.navigation_system import BaseNavigationSystem
from src.control_system import BaseControlSystem
from src.config import CONTROL_SYSTEM_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME


class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        
        # имена очередей блоков находятся в файле src/config.py
        # события нужно отправлять в соответствие с диаграммой информационных потоков
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # события передаются в виде экземпляров класса Event, 
        # описание класса находится в файле src/event_types.py
        control_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                             destination=safety_q_name,
                             operation="set_mission", parameters=self._mission)

        # поиск в каталоге нужной очереди (в данном случае - системы управления)
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        # отправка события в найденную очередь
        control_q.put(control_event)
        safety_q.put(safety_event)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        control_event = Event(source=self.event_source_name,
                              destination=control_q_name,
                              operation="position_update",
                              parameters=self._position)
        safety_event = Event(source=self.event_source_name,
                             destination=safety_q_name,
                             operation="position_update",
                             parameters=self._position)
        
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        control_q.put(control_event)
        safety_q.put(safety_event)
    

class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # инициализация сообщения с желаемой скоростью
        # подсказка: блок Приводы ожидает команду "set_speed" с параметром в виде скорости
        event_speed = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="set_speed",
            parameters=speed
        ) # <-- измените эту строку!

        # отправка сообщения с желаемым направлением
        # подсказка: блок Приводы ожидает команду "set_direction" с параметром в виде направления
        event_direction = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="set_direction",
            parameters=direction
        ) # <-- измените эту строку!

        safety_q.put(event_speed)
        safety_q.put(event_direction)

    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        safety_q = self._queues_dir.get_queue(safety_q_name)
        # инициализация сообщения с командой на блокировку грузового отсека
        # подсказка: блок CargoBay ожидает команду "lock_cargo" без параметров
        event = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="lock_cargo",
            parameters=None
        ) # <-- измените эту строку!
        safety_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        safety_q = self._queues_dir.get_queue(safety_q_name)
        # инициализация сообщения с командой на блокировку грузового отсека
        # подсказка: блок CargoBay ожидает команду "release_cargo" без параметров
        event = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="release_cargo",
            parameters=None
        ) # <-- измените эту строку!

        safety_q.put(event)

# 3. создайте экземпляры изменённых классов и отправьте машинку по ранее предложенному маршруту

queues_dir = QueuesDirectory() 

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

# создадим все остальные компоненты

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)
    

# соберём все компоненты для запуска

# в зависимости от наличия СУПА используем разный набор компонентов - с передачей телеметрии или без

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(30)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 17:56:05.917088
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][CONTROL] новая скорость 30 (была 0)
# [ИНФО][CONTROL] новое направление 12 (было 0)
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9416s N, 30 20m 11.0868s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9416s N, 30 20m 11.0868s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9416s N, 30 20m 11.0868s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9416s N, 30 20m 11.0868s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9679s N, 30 20m 11.0982s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9942s N, 30 20m 11.1095s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0205s N, 30 20m 11.1209s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0469s N, 30 20m 11.1323s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0732s N, 30 20m 11.1436s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0995s N, 30 20m 11.155s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1258s N, 30 20m 11.1664s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1521s N, 30 20m 11.1777s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1784s N, 30 20m 11.1891s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2048s N, 30 20m 11.2005s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2311s N, 30 20m 11.2119s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2574s N, 30 20m 11.2232s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2837s N, 30 20m 11.2346s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 30)
# [ИНФО][CONTROL] новое направление 279 (было 12)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.31s N, 30 20m 11.246s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 279.86585109867605 на 99.86585109867605.
# [ИНФО][CONTROL] новое направление 280 (было 279)
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3363s N, 30 20m 11.2574s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 280.95608068760384 на 100.95608068760384.
# [ИНФО][CONTROL] новое направление 282 (было 280)
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3626s N, 30 20m 11.2688s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.0472361062833 на 102.04723610628332.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3534s N, 30 20m 11.3745s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.132843767124 на 102.13284376712397.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3432s N, 30 20m 11.4799s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.180564765593 на 102.18056476559298.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3319s N, 30 20m 11.5848s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.1854649830962 на 102.18546498309621.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3206s N, 30 20m 11.6897s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.18695736534903 на 102.18695736534903.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3093s N, 30 20m 11.7946s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.188588753695 на 102.188588753695.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3093s N, 30 20m 11.7946s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.188588753695 на 102.188588753695.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2979s N, 30 20m 11.8995s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.188024253141 на 102.18802425314101.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2866s N, 30 20m 12.0044s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.1871455173701 на 102.18714551737008.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2752s N, 30 20m 12.1093s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.1860875999789 на 102.18608759997892.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2638s N, 30 20m 12.2142s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.1849058619081 на 102.18490586190808.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2525s N, 30 20m 12.3191s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.1834772015298 на 102.1834772015298.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2411s N, 30 20m 12.424s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.1818600318452 на 102.18186003184519.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2297s N, 30 20m 12.5289s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.18005434024616 на 102.18005434024616.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2184s N, 30 20m 12.6338s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.17804125939756 на 102.17804125939756.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.207s N, 30 20m 12.7386s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.1757847582678 на 102.17578475826781.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1956s N, 30 20m 12.8435s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.1732311526922 на 102.17323115269221.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1843s N, 30 20m 12.9484s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.1703178685312 на 102.17031786853119.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1729s N, 30 20m 13.0533s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.16714372931733 на 102.16714372931733.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1615s N, 30 20m 13.1582s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.1634440424424 на 102.16344404244239.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1502s N, 30 20m 13.2631s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.15903601702536 на 102.15903601702536.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1388s N, 30 20m 13.368s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.15409296652 на 102.15409296652001.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1275s N, 30 20m 13.4729s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.14787754209505 на 102.14787754209505.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1161s N, 30 20m 13.5778s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.139622893058 на 102.139622893058.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1048s N, 30 20m 13.6827s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.12768570089906 на 102.12768570089906.
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 160 (была 60)
# [ИНФО][CONTROL] новое направление 15 (было 282)
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0934s N, 30 20m 13.7876s E
# [ИНФО][CONTROL] новое направление 14 (было 15)
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0821s N, 30 20m 13.8925s E
# [ИНФО][CONTROL] новое направление 13 (было 14)
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0708s N, 30 20m 13.9974s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0594s N, 30 20m 14.1023s E
# [ИНФО][CONTROL] новое направление 12 (было 13)
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0481s N, 30 20m 14.2072s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1001s N, 30 20m 14.2351s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1523s N, 30 20m 14.2621s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2045s N, 30 20m 14.288s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2569s N, 30 20m 14.313s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3094s N, 30 20m 14.3369s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3619s N, 30 20m 14.3608s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.4144s N, 30 20m 14.3847s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.4669s N, 30 20m 14.4086s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.5194s N, 30 20m 14.4325s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.5719s N, 30 20m 14.4563s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.6244s N, 30 20m 14.4802s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.6769s N, 30 20m 14.504s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.7294s N, 30 20m 14.5279s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.7819s N, 30 20m 14.5517s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.8344s N, 30 20m 14.5756s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.8869s N, 30 20m 14.5995s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.9395s N, 30 20m 14.6233s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.992s N, 30 20m 14.6472s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.0445s N, 30 20m 14.671s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.097s N, 30 20m 14.6949s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.1495s N, 30 20m 14.7188s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.202s N, 30 20m 14.7426s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.2545s N, 30 20m 14.7665s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.307s N, 30 20m 14.7904s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.3595s N, 30 20m 14.8142s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.412s N, 30 20m 14.8381s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.4645s N, 30 20m 14.8619s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.517s N, 30 20m 14.8858s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.5695s N, 30 20m 14.9097s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.622s N, 30 20m 14.9335s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.6745s N, 30 20m 14.9574s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.727s N, 30 20m 14.9813s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.7795s N, 30 20m 15.0051s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.8321s N, 30 20m 15.029s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.8846s N, 30 20m 15.0529s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.9371s N, 30 20m 15.0768s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.9896s N, 30 20m 15.1006s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.0421s N, 30 20m 15.1245s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.0946s N, 30 20m 15.1484s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.1471s N, 30 20m 15.1722s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.1996s N, 30 20m 15.1961s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.2521s N, 30 20m 15.22s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.3046s N, 30 20m 15.2439s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.3571s N, 30 20m 15.2677s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.4096s N, 30 20m 15.2916s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.4621s N, 30 20m 15.3155s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.5146s N, 30 20m 15.3394s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.5671s N, 30 20m 15.3632s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.6196s N, 30 20m 15.3871s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.6721s N, 30 20m 15.411s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.7246s N, 30 20m 15.4349s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.7771s N, 30 20m 15.4587s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.8296s N, 30 20m 15.4826s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.8821s N, 30 20m 15.5065s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.9347s N, 30 20m 15.5304s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.9872s N, 30 20m 15.5543s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.0397s N, 30 20m 15.5782s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.0922s N, 30 20m 15.602s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.1447s N, 30 20m 15.6259s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.1972s N, 30 20m 15.6498s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.2497s N, 30 20m 15.6737s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.3022s N, 30 20m 15.6976s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.3547s N, 30 20m 15.7215s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.4072s N, 30 20m 15.7454s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.4597s N, 30 20m 15.7693s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.5122s N, 30 20m 15.7931s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.5647s N, 30 20m 15.817s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.6172s N, 30 20m 15.8409s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.6697s N, 30 20m 15.8648s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.7222s N, 30 20m 15.8887s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.7747s N, 30 20m 15.9126s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.8272s N, 30 20m 15.9365s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.8797s N, 30 20m 15.9604s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.9322s N, 30 20m 15.9843s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.9847s N, 30 20m 16.0082s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.0372116s N, 30 20m 16.0321s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.089713s N, 30 20m 16.056s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.142214s N, 30 20m 16.0799s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.194715s N, 30 20m 16.1038s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.247216s N, 30 20m 16.1278s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.299717s N, 30 20m 16.1517s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.352218s N, 30 20m 16.1756s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.404718s N, 30 20m 16.1995s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.457218s N, 30 20m 16.2234s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.509718s N, 30 20m 16.2473s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.562218s N, 30 20m 16.2712s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.614717s N, 30 20m 16.2952s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.667217s N, 30 20m 16.3191s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.719716s N, 30 20m 16.343s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.772215s N, 30 20m 16.3669s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.824713s N, 30 20m 16.3909s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.877211s N, 30 20m 16.4148s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.929709s N, 30 20m 16.4387s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.982206s N, 30 20m 16.4627s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.0347s N, 30 20m 16.4866s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.0872s N, 30 20m 16.5106s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.1397s N, 30 20m 16.5345s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.19219s N, 30 20m 16.5585s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.24469s N, 30 20m 16.5824s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.29718s N, 30 20m 16.6064s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.34967s N, 30 20m 16.6304s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 160)
# [ИНФО][CONTROL] новое направление 296 (было 12)
# [ИНФО][CONTROL] новое направление 292 (было 296)
# [ОШИБКА][SAFETY] ошибка открытия грузового отсека. Не достигнута кончная точка маршрута.
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.45466s N, 30 20m 16.6783s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 296.18656583106497 на 292.97968724211626.
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.45466s N, 30 20m 16.6783s E
# [ИНФО][CONTROL] новое направление 289 (было 292)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.50715s N, 30 20m 16.7023s E
# [ИНФО][CONTROL] новое направление 286 (было 289)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.55964s N, 30 20m 16.7264s E
# [ИНФО][CONTROL] новое направление 283 (было 286)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.61212s N, 30 20m 16.7504s E
# [ИНФО][CONTROL] новое направление 282 (было 283)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.63315s N, 30 20m 16.6516s E
# [ИНФО][CONTROL] новое направление 281 (было 282)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.65131s N, 30 20m 16.5506s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.66651s N, 30 20m 16.4476s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.67867s N, 30 20m 16.3431s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.69027s N, 30 20m 16.2383s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.70142s N, 30 20m 16.1333s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.71229s N, 30 20m 16.0282s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.72306s N, 30 20m 15.923s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.73376s N, 30 20m 15.8179s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.74441s N, 30 20m 15.7127s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.75505s N, 30 20m 15.6075s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.76568s N, 30 20m 15.5023s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.7763s N, 30 20m 15.3971s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.7869s N, 30 20m 15.2919s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][SAFETY] сегмент пройден[ИНФО][CONTROL] новое направление 5 (было 281)
#
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.7975s N, 30 20m 15.1866s E[ИНФО][CONTROL] новое направление 8 (было 5)
#
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.80808s N, 30 20m 15.0814s E
# [ИНФО][CONTROL] новое направление 12 (было 8)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.81866s N, 30 20m 14.9762s E[ИНФО][CONTROL] новое направление 16 (было 12)
#
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.8292s N, 30 20m 14.871s E[ИНФО][CONTROL] новое направление 19 (было 16)
#
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.83973s N, 30 20m 14.7657s E
# [ИНФО][CONTROL] новое направление 20 (было 19)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.89293s N, 30 20m 14.7824s E[ИНФО][CONTROL] новое направление 21 (было 20)
#
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.94613s N, 30 20m 14.7991s E
# [ИНФО][CONTROL] новое направление 22 (было 21)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.99869s N, 30 20m 14.8225s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.04933s N, 30 20m 14.859s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.09997s N, 30 20m 14.8956s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.15009s N, 30 20m 14.9348s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.2002s N, 30 20m 14.9741s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.25001s N, 30 20m 15.0149s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.29973s N, 30 20m 15.0562s E
# [ИНФО][CONTROL] новое направление 23 (было 22)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.34941s N, 30 20m 15.0976s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.39904s N, 30 20m 15.1393s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.44865s N, 30 20m 15.181s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 60)
# [ИНФО][CONTROL] новое направление 296 (было 23)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.49823s N, 30 20m 15.2229s E
# [ИНФО][CONTROL] новое направление 292 (было 296)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.5478s N, 30 20m 15.2649s E
# [ИНФО][CONTROL] новое направление 289 (было 292)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.59735s N, 30 20m 15.3069s E
# [ИНФО][CONTROL] новое направление 285 (было 289)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.64688s N, 30 20m 15.349s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.65491s N, 30 20m 15.3171s E
# [ИНФО][CONTROL] новое направление 284 (было 285)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.66187s N, 30 20m 15.2841s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.66772s N, 30 20m 15.2503s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.67246s N, 30 20m 15.2158s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.67712s N, 30 20m 15.1812s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.68172s N, 30 20m 15.1466s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.6863s N, 30 20m 15.1121s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.69088s N, 30 20m 15.0775s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.69545s N, 30 20m 15.0429s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.70002s N, 30 20m 15.0083s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.70459s N, 30 20m 14.9737s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.70916s N, 30 20m 14.9391s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.71373s N, 30 20m 14.9045s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.7183s N, 30 20m 14.8699s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.72287s N, 30 20m 14.8353s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.72743s N, 30 20m 14.8007s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.732s N, 30 20m 14.7661s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.73657s N, 30 20m 14.7315s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.74114s N, 30 20m 14.6969s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.74571s N, 30 20m 14.6623s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.75028s N, 30 20m 14.6278s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.75484s N, 30 20m 14.5932s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.75941s N, 30 20m 14.5586s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.76398s N, 30 20m 14.524s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.76854s N, 30 20m 14.4894s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.77311s N, 30 20m 14.4548s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.77767s N, 30 20m 14.4202s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.78224s N, 30 20m 14.3856s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.7868s N, 30 20m 14.351s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.79137s N, 30 20m 14.3164s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.79593s N, 30 20m 14.2818s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.8005s N, 30 20m 14.2472s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.80506s N, 30 20m 14.2126s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.80962s N, 30 20m 14.178s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.81418s N, 30 20m 14.1434s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.81874s N, 30 20m 14.1088s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.8233s N, 30 20m 14.0742s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 359 (было 284)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.82786s N, 30 20m 14.0396s E
# [ИНФО][CONTROL] новое направление 1 (было 359)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.83242s N, 30 20m 14.005s E
# [ИНФО][CONTROL] новое направление 3 (было 1)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.83698s N, 30 20m 13.9704s E
# [ИНФО][CONTROL] новое направление 6 (было 3)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.84153s N, 30 20m 13.9358s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.85948s N, 30 20m 13.9353s E
# [ИНФО][CONTROL] новое направление 7 (было 6)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.87743s N, 30 20m 13.9349s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.89538s N, 30 20m 13.9358s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.91329s N, 30 20m 13.9383s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.93113s N, 30 20m 13.9422s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.94896s N, 30 20m 13.9464s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.96678s N, 30 20m 13.9507s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.98458s N, 30 20m 13.9553s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.00238s N, 30 20m 13.9599s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.02018s N, 30 20m 13.9646s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.03798s N, 30 20m 13.9693s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.05577s N, 30 20m 13.974s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.07356s N, 30 20m 13.9788s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.09135s N, 30 20m 13.9835s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.09135s N, 30 20m 13.9835s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][CONTROL] маршрут пройден, текущее время 17:56:30.906241
# [ИНФО][CONTROL] новая скорость 0.0 (была 20)
# [ИНФО][CONTROL] новое направление 0 (было 7)
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.10915s N, 30 20m 13.9883s E
# [ОШИБКА][SAFETY] ошибка обработки команд: 'NoneType' object has no attribute 'longitude'
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# #### *Опциональное задание повышенной сложности* Обеспечение ЦБ2
#
# **Перед началом работы над этой задачей рекомендуем сохранить все текущие изменения в git репозитории (git commit, git push).**
#
# Напомним цель безопасности №2 (ЦБ2): "При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут"
#
# Обеспечение ЦБ2 потребует
# - внедрения механизма **контроля аутентичности маршрутного задания** (mission), а значит
# - помимо изменения **блока безопасности** (SafetyBlock), модификации
#   - системы **планирования задания** (MissionPlanner)
#   - **коммуникационного шлюза** (CommunicationGateway)
#   - и, возможно, **системы управления** (ControlSystem).
#
# Для решения этой задачи допустимо менять код соответствующих модулей в папке src.
#
# Возможным решением является внедрение механизма цифровой подписи, верификацией которой будет заниматься блок безопасности. В этой ситуации если коммуникационный шлюз (блок "1. Связь" на рис. 5 в модуле 1) оказался скомпрометированным и изменил маршрутное задание, оно не должно пройти проверку подлинности в блоке безопасности.
#
# **Рекомендуем эту задачу делать в последнюю очередь**, *после успешного выполнения модуля 4*, поскольку успешное выполнение модуля 4 принесёт больше баллов, чем внедрение цифровой подписи и обеспечение ЦБ2.
# К сведению, реализованные в этой версии киберпрепятствия не предполагают компрометацию маршрутного задания.
#
# Конечно, если будут решены все основные задачи и к тому же обеспечен контроль аутентичности маршрутного задания, такая работа с высокой вероятностью окажется лучшей.

# %%
# если вы собираетесь выполнить это задание, напишите в этой ячейке код выполнения изменённых блоков. 
# cам код допускается редактировать в папке src
# в случае успешной реализации машинка должна успешно пройти по маршруту, а в случае искажения маршрутного задания в блоке коммуникационного шлюза должна остаться на месте, 
# при этом именно блок безопасности должен заблокировать движение

# %% [markdown]
# ### Задание 3.2. Монитор безопасности

# %% [markdown]
# В текущей реализации каждый блок сам решает куда и какие данные ему отправлять. Это приемлемо, когда каждый блок рассматривается как благонадёжный. Однако нельзя исключать ситуацию успешной компрометации какого-либо из блоков (одного или нескольких), в результате которой злоумышленник может получить полный контроль над частью системы.
#
# В такой ситуации необходимо выстроить внутреннюю "поверхность защиты", частью этой системы уже является блок "Ограничитель", однако необходимо сделать так, чтобы соответствующие запросы проходили только через него, а не в обход.
#
# Для решения этой задачи необходимо добавить новый блок "Монитор безопасности". Его задача - обеспечить контроль направления информационных потоков, допустить передачу данных только между теми блоками и в тех направлениях, которые задуманы архитектором системы. Тогда, например, попытка передать команду из системы управления напрямую в сервоприводы в обход ограничителя будет заблокирована.
#
# Возможно, возникнет вопрос, а что помешает злоумышленнику отправить команду в обход этого монитора безопасности. В рамках этой учебной инфраструктуры особо ничего, однако при разработке реальной системы можно использовать специализированные микроядерные операционные системы, такие как, например, KasperskyOS, которые обеспечат обязательное вовлечение монитора безопасности в контроль взаимодействия между блоками.
#
# Архитектура системы для решения задачи 3.2 должна выглядеть как на рис.8:
#
# ![Архитектура системы с монитором безопасности](images/ciac-arch-m32.png)
#
# Рис. 8. Архитектура бортовых систем с монитором безопасности

# %% [markdown]
# Базовый класс модуля безопасности находится в файле src/security_monitor.py, его менять не нужно.
#
# В следующей ячейке находится реализация класса SecurityMonitor

# %%
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission')
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %% [markdown]
# Обратите внимание на этот код:
# ```python
#     def _init_set_security_policies(self):
#         """ инициализация политик безопасности """
#         default_policies = [
#             SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
#         ]
#         self.set_security_policies(policies=default_policies)
# ```
#
# В нём инициализируется политика безопасности, разрешающая запрос set_mission от коммуникационного шлюза в систему управления.
#
# Код политики безопасности в строка 6-9:
# ```python
# SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
# ```
#
# Шаблон политики безопасности описан в файле src/security_policy_type.py:
# ```python
# @dataclass
# class SecurityPolicy:
#     """ политика безопасности """
#     source: str         # отправитель запроса
#     destination: str    # получатель
#     operation: str      # запрашиваемая операция
#
# ```
#
# По аналогии в методе _init_set_security_policies допишите другие политики безопасности, чтобы разрешить взаимодействия согласно диаграмме на рис.7. выше.

# %% [markdown]
# Теперь необходимо изменить взаимодействие между блоками так, чтобы оно всегда проходило через монитор безопасности. Для этого потребуется изменить соответствующие реализации внутренних блоков.

# %% [markdown]
# Ниже пример для блока навигации. Обратите внимание на выделенные строки и комментарии.
#
# ```python
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         # событие для системы управления,
#         # поэтому в destination указываем CONTROL_SYSTEM_QUEUE_NAME
#         event = Event(source=self.event_source_name,
# >>>                      destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         # но событие отправляем сначала на проверку в монитор безопасности,
#         # поэтому используем очередь с именем SECURITY_MONITOR_QUEUE_NAME
# >>>        security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#         # а в систему управления наше событие монитор безопасности отправит сам, если найдёт разрешающую эту операцию политику безопасности
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)
# ```

# %% [markdown]
# ```python
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         event = Event(source=self.event_source_name,
#                       destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)
# ```

# %% [markdown]
# В файле tests/module/test_security_monitor.py можно увидеть тест логики работы монитора безопасности. Запустить его можно следующей командой:

# %%
# !pytest -svk security_monitor
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.7, pytest-8.3.4, pluggy-1.5.0 -- /home/max/ghq/github.com/minmaxik/cyberimmune-autonomy--chvt-preview/.venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/max/ghq/github.com/minmaxik/cyberimmune-autonomy--chvt-preview
# configfile: pytest.ini
# testpaths: tests
# collected 1 item
#
# tests/module/test_security_monitor.py::test_security_policies [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='control', operation='set_mission', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='cargo', operation='release_cargo', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# PASSED
#
# ============================== 1 passed in 0.01s ===============================

# %% [markdown]
# В одном кодовом блоке ниже (или нескольких - как будет удобнее)  сделайте следующее
#
# 1. Измените реализацию монитора безопасности в части правил проверки передаваемых сообщений в мониторе безопасности
# 2. Измените параметры отправки сообщений между элементами бортовых систем (блоками 1-7), чтобы они всегда отправлялись в очередь монитора безопасности (отправитель и получатель при этом не меняются)
# 3. После всех изменений убедитесь в том, что машинка по-прежнему успешно выполняет маршрутное задание и доставляет груз
# 4. Дополнительные баллы принесут автоматические тесты правил безопасности в файле tests/module/test_security_monitor.py - можно проверить, что все новые политики работают как ожидаются, а недопустимые взаимодействия (т.е. таких стрелок нет на рис. 8) блокируются

# %%
# добавьте изменения сюда
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME,NAVIGATION_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO, SECURITY_MONITOR_QUEUE_NAME
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission'),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='position_update'),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_mission'),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_speed'),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_direction'),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='lock_cargo'),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='release_cargo'),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=NAVIGATION_QUEUE_NAME,
                operation='request_position'),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_speed'),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_direction'),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='lock_cargo'),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='release_cargo'),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='position_update'),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='position_update'),
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized


# напишите свой код в этой ячейке, запустите машинку по маршруту, убедитесь, 
# что в конечной (и только в конечной!) точке CargoBay получает команду и успешно выполняет выгрузку

from src.safety_block import BaseSafetyBlock
from src.config import LOG_DEBUG, LOG_INFO, LOG_ERROR, DEFAULT_LOG_LEVEL
from src.control_system import BaseControlSystem

class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления    
        if not self._position:
            self._log_message(LOG_ERROR, "неизвестны текущие координаты. Разворот в стандартное положение.")
            self._direction = 0;
        elif not self._mission:
            self._log_message(LOG_ERROR, "отсутствует заданный маршрут. Разворот в стандартное положение.")
            self._direction = 0;
        else:
            pos = self._position
            dst = self._route.next_point();
            # self._log_message(LOG_DEBUG, f"{pos}\n, {dst}\n, {self._route.current_index}\n, {self._route.calculate_remaining_distance_to_next_point(self._position)}")
            assumed_direction = BaseControlSystem._calculate_bearing(None, pos, dst)

            if direction != assumed_direction:
                self._log_message(LOG_ERROR, f"произошло отклонение от маршрута. Произведена корректировка {direction} на {assumed_direction}.")
            self._direction = assumed_direction

        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        # TODO реализовать контроль безопасности изменения скорости
        if not self._position:
            self._log_message(LOG_ERROR, "неизвестны текущие координаты. Остановка.")
            self._speed = 0;
        elif not self._mission:
            self._log_message(LOG_ERROR, "отсутствует заданный маршрут. Остановка.")
            self._speed = 0;
        else:
            allowed_speed = self._route.calculate_speed()
            if (speed > allowed_speed):
                self._log_message(LOG_ERROR, f"превышен лимит скорости на текущем участке. ({speed}/{allowed_speed}). Ограничиваем до {allowed_speed}")
                self._speed = allowed_speed
            else:
                self._speed = speed
        self._send_speed_to_consumers()


    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )

        security_monitor_q_name = SECURITY_MONITOR_QUEUE_NAME
        security_monitor_q: Queue = self._queues_dir.get_queue(security_monitor_q_name)
        security_monitor_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME

        # отправка сообщения с желаемой скоростью
        event_direction = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )

        security_monitor_q_name = SECURITY_MONITOR_QUEUE_NAME
        security_monitor_q: Queue = self._queues_dir.get_queue(security_monitor_q_name)
        security_monitor_q.put(event_direction)

    def _lock_cargo(self, _):
        self._log_message(LOG_DEBUG, "блокировка грузового отсека")
        self._send_lock_cargo_to_consumers();
        
    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем команду блокировки грузового отсека получателям")

        cargo_q_name = CARGO_BAY_QUEUE_NAME

        # отправка сообщения с желаемой скоростью
        event_lock_cargo = Event(source=self.event_source_name,
                            destination=cargo_q_name,
                            operation="lock_cargo",
                            parameters=None
                            )

        security_monitor_q_name = SECURITY_MONITOR_QUEUE_NAME
        security_monitor_q: Queue = self._queues_dir.get_queue(security_monitor_q_name)
        security_monitor_q.put(event_lock_cargo)

    def _release_cargo(self, _):
        if not self._route:
            self._log_message(LOG_ERROR, "ошибка открытия грузового отсека. Отсутствует маршрут.")
            return
        if not self._route.route_finished:
            self._log_message(LOG_ERROR, "ошибка открытия грузового отсека. Не достигнута кончная точка маршрута.")
            return
        self._send_release_cargo_to_consumers()
            
    
    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем команду разблокировки грузового отсека получателям")

        cargo_q_name = CARGO_BAY_QUEUE_NAME

        # отправка сообщения с желаемой скоростью
        event_release_cargo = Event(source=self.event_source_name,
                            destination=cargo_q_name,
                            operation="release_cargo",
                            parameters=None
                            )

        security_monitor_q_name = SECURITY_MONITOR_QUEUE_NAME
        security_monitor_q: Queue = self._queues_dir.get_queue(security_monitor_q_name)
        security_monitor_q.put(event_release_cargo)

# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

from multiprocessing import Queue
from src.event_types import Event
from src.communication_gateway import BaseCommunicationGateway
from src.navigation_system import BaseNavigationSystem
from src.control_system import BaseControlSystem
from src.config import CONTROL_SYSTEM_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME


class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        
        # имена очередей блоков находятся в файле src/config.py
        # события нужно отправлять в соответствие с диаграммой информационных потоков
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # события передаются в виде экземпляров класса Event, 
        # описание класса находится в файле src/event_types.py
        control_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                             destination=safety_q_name,
                             operation="set_mission", parameters=self._mission)

        
        security_monitor_q_name = SECURITY_MONITOR_QUEUE_NAME
        security_monitor_q: Queue = self._queues_dir.get_queue(security_monitor_q_name)
        # отправка события в найденную очередь
        security_monitor_q.put(control_event)
        security_monitor_q.put(safety_event)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        control_event = Event(source=self.event_source_name,
                              destination=control_q_name,
                              operation="position_update",
                              parameters=self._position)
        safety_event = Event(source=self.event_source_name,
                             destination=safety_q_name,
                             operation="position_update",
                             parameters=self._position)
        
        security_monitor_q_name = SECURITY_MONITOR_QUEUE_NAME
        security_monitor_q: Queue = self._queues_dir.get_queue(security_monitor_q_name)

        security_monitor_q.put(control_event)
        security_monitor_q.put(safety_event)
    

class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # инициализация сообщения с желаемой скоростью
        # подсказка: блок Приводы ожидает команду "set_speed" с параметром в виде скорости
        event_speed = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="set_speed",
            parameters=speed
        ) # <-- измените эту строку!

        # отправка сообщения с желаемым направлением
        # подсказка: блок Приводы ожидает команду "set_direction" с параметром в виде направления
        event_direction = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="set_direction",
            parameters=direction
        ) # <-- измените эту строку!

        security_monitor_q_name = SECURITY_MONITOR_QUEUE_NAME
        security_monitor_q: Queue = self._queues_dir.get_queue(security_monitor_q_name)

        security_monitor_q.put(event_speed)
        security_monitor_q.put(event_direction)

    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # инициализация сообщения с командой на блокировку грузового отсека
        # подсказка: блок CargoBay ожидает команду "lock_cargo" без параметров
        event = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="lock_cargo",
            parameters=None
        ) # <-- измените эту строку!
        security_monitor_q_name = SECURITY_MONITOR_QUEUE_NAME
        security_monitor_q: Queue = self._queues_dir.get_queue(security_monitor_q_name)

        security_monitor_q.put(event)
        

    def _release_cargo(self):
        """ открыть грузовой отсек """
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        # инициализация сообщения с командой на блокировку грузового отсека
        # подсказка: блок CargoBay ожидает команду "release_cargo" без параметров
        event = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="release_cargo",
            parameters=None
        ) # <-- измените эту строку!

        security_monitor_q_name = SECURITY_MONITOR_QUEUE_NAME
        security_monitor_q: Queue = self._queues_dir.get_queue(security_monitor_q_name)

        security_monitor_q.put(event)

# 3. создайте экземпляры изменённых классов и отправьте машинку по ранее предложенному маршруту

queues_dir = QueuesDirectory() 

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

# создадим все остальные компоненты

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)

security = SecurityMonitor(queues_dir=queues_dir)
    

# соберём все компоненты для запуска

# в зависимости от наличия СУПА используем разный набор компонентов - с передачей телеметрии или без

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block,
        security
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block,
        security
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(30)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='communication', destination='control', operation='position_update'), SecurityPolicy(source='communication', destination='safety', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed'), SecurityPolicy(source='control', destination='safety', operation='set_direction'), SecurityPolicy(source='control', destination='safety', operation='lock_cargo'), SecurityPolicy(source='control', destination='safety', operation='release_cargo'), SecurityPolicy(source='control', destination='navigation', operation='request_position'), SecurityPolicy(source='safety', destination='servos', operation='set_speed'), SecurityPolicy(source='safety', destination='servos', operation='set_direction'), SecurityPolicy(source='safety', destination='cargo', operation='lock_cargo'), SecurityPolicy(source='safety', destination='cargo', operation='release_cargo'), SecurityPolicy(source='navigation', destination='control', operation='position_update'), SecurityPolicy(source='navigation', destination='safety', operation='position_update')]
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][SECURITY] старт блока грузового отсека
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 17:56:37.559703
# [ИНФО][CONTROL] новая скорость 30 (была 0)
# [ИНФО][CONTROL] новое направление 12 (было 0)
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9416s N, 30 20m 11.0868s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9416s N, 30 20m 11.0868s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9416s N, 30 20m 11.0868s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9416s N, 30 20m 11.0868s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9679s N, 30 20m 11.0982s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 12.229917083610644 на 12.2310152376225.
# [ИНФО][SAFETY] текущие координаты: 59 55m 55.9942s N, 30 20m 11.1095s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 12.2310152376225 на 12.232240261249274.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0205s N, 30 20m 11.1209s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 12.232240261249274 на 12.233615518332044.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0469s N, 30 20m 11.1323s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 12.233615518332044 на 12.235170487753237.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0732s N, 30 20m 11.1436s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 12.235170487753237 на 12.236866166409754.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0995s N, 30 20m 11.155s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 12.236866166409754 на 12.238724785136867.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1258s N, 30 20m 11.1664s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 12.238724785136867 на 12.240773915379691.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1521s N, 30 20m 11.1777s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 12.240773915379691 на 12.243048283862208.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1784s N, 30 20m 11.1891s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 12.243048283862208 на 12.245599902972344.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2048s N, 30 20m 11.2005s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 12.245599902972344 на 12.248500796531289.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2311s N, 30 20m 11.2119s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 12.248500796531289 на 12.251854413904482.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2574s N, 30 20m 11.2232s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 12.251854413904482 на 12.255816213708329.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2837s N, 30 20m 11.2346s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 12.255816213708329 на 12.260632253012204.
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.31s N, 30 20m 11.246s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 12.260632253012204 на 99.86586469458575.
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 30)
# [ИНФО][CONTROL] новое направление 279 (было 12)
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3363s N, 30 20m 11.2574s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 279.86586469458575 на 100.95608902550157.
# [ИНФО][CONTROL] новое направление 280 (было 279)
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3626s N, 30 20m 11.2688s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 280.95608902550157 на 102.04723764737349.
# [ИНФО][CONTROL] новое направление 282 (было 280)
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.389s N, 30 20m 11.2802s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.0472376473735 на 103.13852438117055.
# [ИНФО][CONTROL] новое направление 283 (было 282)
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.389s N, 30 20m 11.2802s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.13852438117055 на 103.13852438117055.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3843s N, 30 20m 11.333s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.2016221249343 на 103.20162212493432.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3741s N, 30 20m 11.4384s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.2016221249343 на 103.29145795006502.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3629s N, 30 20m 11.5433s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.291457950065 на 103.34293626143267.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3506s N, 30 20m 11.6478s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.34293626143267 на 103.35098757410083.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3384s N, 30 20m 11.7523s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.3509875741008 на 103.35977655122576.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3261s N, 30 20m 11.8568s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.35977655122576 на 103.36940960977864.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3138s N, 30 20m 11.9613s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.36940960977864 на 103.37682230572148.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3015s N, 30 20m 12.0657s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.3768223057215 на 103.38023545250104.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.289s N, 30 20m 12.1701s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.38023545250104 на 103.38113356085387.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2766s N, 30 20m 12.2745s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.38113356085387 на 103.3816570178027.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2642s N, 30 20m 12.3789s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.3816570178027 на 103.38168788302193.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2517s N, 30 20m 12.4833s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.3816878830219 на 103.38106912934143.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2392s N, 30 20m 12.5877s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.3810691293414 на 103.37982069233709.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2268s N, 30 20m 12.6921s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.3798206923371 на 103.37810798384169.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2143s N, 30 20m 12.7965s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.3781079838417 на 103.37602648250947.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2019s N, 30 20m 12.9009s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.3760264825095 на 103.37355700803164.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1894s N, 30 20m 13.0053s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.37355700803164 на 103.37052406149832.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1769s N, 30 20m 13.1097s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.3705240614983 на 103.36686901189887.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1645s N, 30 20m 13.2141s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.36686901189887 на 103.36243336126785.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.152s N, 30 20m 13.3185s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.36243336126785 на 103.35694086954959.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1395s N, 30 20m 13.4229s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.3569408695496 на 103.34990817651345.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1271s N, 30 20m 13.5273s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.34990817651345 на 103.34045266644489.
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1146s N, 30 20m 13.6317s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.3404526664449 на 103.3268077674004.
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1022s N, 30 20m 13.7361s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 283.3268077674004 на 15.35730918984234.
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 160 (была 60)
# [ИНФО][CONTROL] новое направление 15 (было 283)
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0897s N, 30 20m 13.8405s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 15.35730918984234 на 14.811874855250267.
# [ИНФО][CONTROL] новое направление 14 (было 15)
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0773s N, 30 20m 13.9449s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 14.811874855250267 на 14.266181676657709.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0649s N, 30 20m 14.0493s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 14.266181676657709 на 13.720326779885.
# [ИНФО][CONTROL] новое направление 13 (было 14)
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.0525s N, 30 20m 14.1537s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.720326779885 на 13.174406555966073.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1044s N, 30 20m 14.1822s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.174406555966073 на 13.153625022060965.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.1565s N, 30 20m 14.2096s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.153625022060965 на 13.137734388320212.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.2087s N, 30 20m 14.236s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.137734388320212 на 13.12688261029291.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.261s N, 30 20m 14.2615s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.12688261029291 на 13.121222178826713.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3134s N, 30 20m 14.286s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.121222178826713 на 13.120910310931038.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.3659s N, 30 20m 14.3104s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.120910310931038 на 13.120802102621042.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.4183s N, 30 20m 14.3348s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.120802102621042 на 13.120691620977482.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.4707s N, 30 20m 14.3592s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.120691620977482 на 13.120854658524252.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.5232s N, 30 20m 14.3835s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.120854658524252 на 13.121080038855496.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.5756s N, 30 20m 14.4079s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.121080038855496 на 13.121313397684673.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.6281s N, 30 20m 14.4322s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.121313397684673 на 13.121552821717955.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.6805s N, 30 20m 14.4566s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.121552821717955 на 13.121798531974889.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.733s N, 30 20m 14.481s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.121798531974889 на 13.12204775869742.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.7854s N, 30 20m 14.5053s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.12204775869742 на 13.12229993230892.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.8379s N, 30 20m 14.5297s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.12229993230892 на 13.122555062465835.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.8903s N, 30 20m 14.554s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.122555062465835 на 13.122813180920673.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.9428s N, 30 20m 14.5784s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.122813180920673 на 13.123074318168676.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 56.9952s N, 30 20m 14.6028s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.123074318168676 на 13.123338538445523.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.0477s N, 30 20m 14.6271s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.123338538445523 на 13.123605915012092.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.1001s N, 30 20m 14.6515s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.123605915012092 на 13.123876524813909.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.1526s N, 30 20m 14.6759s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.123876524813909 на 13.124150447921522.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.205s N, 30 20m 14.7002s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.124150447921522 на 13.124427768147257.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.2575s N, 30 20m 14.7246s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.124427768147257 на 13.12470857227919.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.3099s N, 30 20m 14.7489s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.12470857227919 на 13.124996255173642.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.3624s N, 30 20m 14.7733s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.124996255173642 на 13.125284343481667.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.4148s N, 30 20m 14.7977s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.125284343481667 на 13.125576198714612.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.4673s N, 30 20m 14.822s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.125576198714612 на 13.125871922472982.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.5197s N, 30 20m 14.8464s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.125871922472982 на 13.126171620878836.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.5722s N, 30 20m 14.8708s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.126171620878836 на 13.126475360392249.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.6246s N, 30 20m 14.8951s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.126475360392249 на 13.126783297947611.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.6771s N, 30 20m 14.9195s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.126783297947611 на 13.127095553104027.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.7295s N, 30 20m 14.9439s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.127095553104027 на 13.127412250660768.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.782s N, 30 20m 14.9682s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.127412250660768 на 13.127733520952177.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.8344s N, 30 20m 14.9926s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.127733520952177 на 13.12805950092718.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.8868s N, 30 20m 15.017s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.12805950092718 на 13.128390333036975.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.9393s N, 30 20m 15.0414s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.128390333036975 на 13.128726165828198.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 57.9917s N, 30 20m 15.0657s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.128726165828198 на 13.129067155592566.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.0442s N, 30 20m 15.0901s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.129067155592566 на 13.129413465148446.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.0966s N, 30 20m 15.1145s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.129413465148446 на 13.129765266103732.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.1491s N, 30 20m 15.1389s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.129765266103732 на 13.130127836099973.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.2015s N, 30 20m 15.1632s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.130127836099973 на 13.13049124657556.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.254s N, 30 20m 15.1876s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 13.13049124657556 на 13.130860716939594.
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.254s N, 30 20m 15.1876s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.3064s N, 30 20m 15.212s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.3589s N, 30 20m 15.2364s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.4113s N, 30 20m 15.2607s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.4638s N, 30 20m 15.2851s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.5162s N, 30 20m 15.3095s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.5687s N, 30 20m 15.3339s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.6211s N, 30 20m 15.3582s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.6735s N, 30 20m 15.3826s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.726s N, 30 20m 15.407s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.7784s N, 30 20m 15.4314s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.8309s N, 30 20m 15.4558s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.8833s N, 30 20m 15.4801s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.9358s N, 30 20m 15.5045s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 58.9882s N, 30 20m 15.5289s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.0407s N, 30 20m 15.5533s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.0931s N, 30 20m 15.5777s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.1456s N, 30 20m 15.6021s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.198s N, 30 20m 15.6265s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.2505s N, 30 20m 15.6508s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.3029s N, 30 20m 15.6752s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.3553s N, 30 20m 15.6996s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.4078s N, 30 20m 15.724s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.4602s N, 30 20m 15.7484s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.5127s N, 30 20m 15.7728s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.5651s N, 30 20m 15.7972s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.6176s N, 30 20m 15.8216s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.67s N, 30 20m 15.846s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.7225s N, 30 20m 15.8704s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.7749s N, 30 20m 15.8948s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.8273s N, 30 20m 15.9192s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.8798s N, 30 20m 15.9436s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.9322s N, 30 20m 15.968s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 55m 59.9847s N, 30 20m 15.9924s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.0371178s N, 30 20m 16.0168s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.0895611s N, 30 20m 16.0412s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.142004s N, 30 20m 16.0656s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.194447s N, 30 20m 16.09s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.24689s N, 30 20m 16.1144s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.299332s N, 30 20m 16.1388s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.351775s N, 30 20m 16.1633s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.404217s N, 30 20m 16.1877s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.456659s N, 30 20m 16.2121s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.509101s N, 30 20m 16.2365s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.561542s N, 30 20m 16.2609s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.613983s N, 30 20m 16.2853s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.666425s N, 30 20m 16.3098s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.718865s N, 30 20m 16.3342s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.771306s N, 30 20m 16.3586s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.823746s N, 30 20m 16.3831s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.876186s N, 30 20m 16.4075s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.928625s N, 30 20m 16.4319s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 0.981064s N, 30 20m 16.4564s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.0335s N, 30 20m 16.4808s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.08594s N, 30 20m 16.5053s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.13838s N, 30 20m 16.5297s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.19082s N, 30 20m 16.5542s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.24325s N, 30 20m 16.5786s E
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.29569s N, 30 20m 16.6031s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 160)
# [ИНФО][CONTROL] новое направление 296 (было 13)
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (160/60). Ограничиваем до 60
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.34812s N, 30 20m 16.6276s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] новое направление 293 (было 296)
# [ОШИБКА][SAFETY] ошибка открытия грузового отсека. Не достигнута кончная точка маршрута.
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.40056s N, 30 20m 16.6521s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.45299s N, 30 20m 16.6766s E
# [ИНФО][CONTROL] новое направление 289 (было 293)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.50543s N, 30 20m 16.7011s E
# [ИНФО][CONTROL] новое направление 286 (было 289)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.55786s N, 30 20m 16.7256s E
# [ИНФО][CONTROL] новое направление 283 (было 286)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.61028s N, 30 20m 16.7501s E
# [ИНФО][CONTROL] новое направление 279 (было 283)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.71514s N, 30 20m 16.7992s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 279.8232619600498 на 276.50614046445065.
# [ИНФО][CONTROL] новое направление 276 (было 279)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.73626s N, 30 20m 16.7005s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 276.50614046445065 на 275.5016684269416.
# [ИНФО][CONTROL] новое направление 275 (было 276)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.75452s N, 30 20m 16.5995s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 275.5016684269416 на 274.57670280310214.
# [ИНФО][CONTROL] новое направление 274 (было 275)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.76982s N, 30 20m 16.4967s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 274.57670280310214 на 273.75132053367025.
# [ИНФО][CONTROL] новое направление 273 (было 274)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.78208s N, 30 20m 16.3922s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 273.75132053367025 на 273.0501171861712.
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.78819s N, 30 20m 16.2855s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 273.0501171861712 на 272.7705822333745.
# [ИНФО][CONTROL] новое направление 272 (было 273)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.79335s N, 30 20m 16.1787s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 272.7705822333745 на 272.5302133510513.
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.79765s N, 30 20m 16.0717s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 272.5302133510513 на 272.33267641383907.
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.80117s N, 30 20m 15.9647s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 272.33267641383907 на 272.18105056790864.
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.80404s N, 30 20m 15.8575s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 272.18105056790864 на 272.0769397725177.
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.80664s N, 30 20m 15.7503s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 272.0769397725177 на 271.98253355254036.
# [ИНФО][CONTROL] новое направление 271 (было 272)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.80902s N, 30 20m 15.6431s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 271.98253355254036 на 271.8962512345886.
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.81121s N, 30 20m 15.5359s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 271.8962512345886 на 271.8146606100488.
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.81326s N, 30 20m 15.4286s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 271.8146606100488 на 271.7305072515003.
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.81521s N, 30 20m 15.3214s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 271.7305072515003 на 271.62752680660026.
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 4 (было 271)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.81707s N, 30 20m 15.2142s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 271.62752680660026 на 4.463291941863417.
# [ИНФО][CONTROL] новое направление 8 (было 4)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.81886s N, 30 20m 15.1069s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 4.463291941863417 на 8.186206213263517.
# [ИНФО][CONTROL] новое направление 11 (было 8)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.82056s N, 30 20m 14.9996s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 8.186206213263517 на 11.855729933809073.
# [ИНФО][CONTROL] новое направление 15 (было 11)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.82219s N, 30 20m 14.8924s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 11.855729933809073 на 15.442736460855883.
# [ИНФО][CONTROL] новое направление 18 (было 15)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.82372s N, 30 20m 14.7851s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 15.442736460855883 на 18.921645369653504.
# [ИНФО][CONTROL] новое направление 19 (было 18)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.87741s N, 30 20m 14.7935s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 18.921645369653504 на 19.87524177481123.
# [ИНФО][CONTROL] новое направление 20 (было 19)
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.93071s N, 30 20m 14.8087s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 19.87524177481123 на 20.703458271444504.
# [ИНФО][SAFETY] текущие координаты: 59 56m 1.98342s N, 30 20m 14.8308s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 20.703458271444504 на 21.380462694353753.
# [ИНФО][CONTROL] новое направление 21 (было 20)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.03533s N, 30 20m 14.8594s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 21.380462694353753 на 21.874305281775662.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.08627s N, 30 20m 14.8942s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 21.874305281775662 на 22.143977971186416.
# [ИНФО][CONTROL] новое направление 22 (было 21)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.13692s N, 30 20m 14.9306s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 22.143977971186416 на 22.37262213299158.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.18757s N, 30 20m 14.9671s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 22.37262213299158 на 22.6517078532421.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.23772s N, 30 20m 15.0063s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 22.6517078532421 на 22.813557814283115.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.28769s N, 30 20m 15.0462s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 22.813557814283115 на 22.951388265051435.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.33757s N, 30 20m 15.0867s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 22.951388265051435 на 23.09025884384215.
# [ИНФО][CONTROL] новое направление 23 (было 22)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.38738s N, 30 20m 15.1275s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 23.09025884384215 на 23.238887387879572.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.43708s N, 30 20m 15.1689s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 23.238887387879572 на 23.39207233885702.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.48672s N, 30 20m 15.2105s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 23.39207233885702 на 23.592572712903518.
# [ИНФО][SAFETY] сегмент пройден
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (60/20). Ограничиваем до 20
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.53631s N, 30 20m 15.2523s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 23.592572712903518 на 293.7162288773814.
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 60)
# [ИНФО][CONTROL] новое направление 293 (было 23)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.58585s N, 30 20m 15.2944s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 293.7162288773814 на 289.93741814119954.
# [ИНФО][CONTROL] новое направление 289 (было 293)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.63533s N, 30 20m 15.3367s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 289.93741814119954 на 286.18671447173676.
# [ИНФО][CONTROL] новое направление 286 (было 289)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.68476s N, 30 20m 15.3794s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 286.18671447173676 на 282.49728215589005.
# [ИНФО][CONTROL] новое направление 282 (было 286)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.73412s N, 30 20m 15.4223s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 282.49728215589005 на 278.8999202793044.
# [ИНФО][CONTROL] новое направление 278 (было 282)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.74134s N, 30 20m 15.3896s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 278.8999202793044 на 278.58073315501474.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.74746s N, 30 20m 15.3559s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 278.58073315501474 на 278.32952898892563.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.75246s N, 30 20m 15.3216s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 278.32952898892563 на 278.15112164420344.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.75635s N, 30 20m 15.2866s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 278.15112164420344 на 278.04978961681513.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.75912s N, 30 20m 15.2513s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 278.04978961681513 на 278.0292154258648.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.7618s N, 30 20m 15.2159s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 278.0292154258648 на 278.0154256381034.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.7644s N, 30 20m 15.1805s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 278.0154256381034 на 278.0072288172528.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.76695s N, 30 20m 15.1451s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 278.0072288172528 на 278.0031877927596.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.76946s N, 30 20m 15.1097s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 278.0031877927596 на 278.0016016253466.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.77198s N, 30 20m 15.0743s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 278.0016016253466 на 277.9999300791319.
# [ИНФО][CONTROL] новое направление 277 (было 278)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.77448s N, 30 20m 15.0389s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.9999300791319 на 277.9991206598685.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.77698s N, 30 20m 15.0035s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.9991206598685 на 277.9984995006495.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.77948s N, 30 20m 14.968s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.9984995006495 на 277.99796097263805.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.78198s N, 30 20m 14.9326s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.99796097263805 на 277.99743817399514.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.78448s N, 30 20m 14.8972s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.99743817399514 на 277.99693524803706.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.78697s N, 30 20m 14.8618s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.99693524803706 на 277.99642631663073.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.78947s N, 30 20m 14.8263s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.99642631663073 на 277.99590451054604.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.79197s N, 30 20m 14.7909s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.99590451054604 на 277.9953656434674.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.79447s N, 30 20m 14.7555s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.9953656434674 на 277.99480732715006.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.79696s N, 30 20m 14.7201s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.99480732715006 на 277.9942266714985.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.79946s N, 30 20m 14.6846s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.9942266714985 на 277.9936213439647.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.80196s N, 30 20m 14.6492s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.9936213439647 на 277.99298889092074.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.80446s N, 30 20m 14.6138s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.99298889092074 на 277.99232664857965.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.80695s N, 30 20m 14.5784s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.99232664857965 на 277.99163158551175.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.80945s N, 30 20m 14.5429s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.99163158551175 на 277.99090025017745.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.81195s N, 30 20m 14.5075s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.99090025017745 на 277.9901286540522.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.81444s N, 30 20m 14.4721s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.9901286540522 на 277.98931212053543.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.81694s N, 30 20m 14.4367s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.98931212053543 на 277.9884451519703.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.81943s N, 30 20m 14.4013s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.9884451519703 на 277.9875211845323.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.82193s N, 30 20m 14.3658s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.9875211845323 на 277.9865323018586.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.82442s N, 30 20m 14.3304s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.9865323018586 на 277.98546891807314.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.82692s N, 30 20m 14.295s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.98546891807314 на 277.9843191645003.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.82941s N, 30 20m 14.2596s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.9843191645003 на 277.98300643994713.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.83191s N, 30 20m 14.2241s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.98300643994713 на 277.9816306572021.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.8344s N, 30 20m 14.1887s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.9816306572021 на 277.9801095045729.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.8369s N, 30 20m 14.1533s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.9801095045729 на 277.9784103166662.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.83939s N, 30 20m 14.1179s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.9784103166662 на 277.9764885434514.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.84188s N, 30 20m 14.0824s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.9764885434514 на 277.97428850306994.
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.84438s N, 30 20m 14.047s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 277.97428850306994 на 358.67699549460957.
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 358 (было 277)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.84687s N, 30 20m 14.0116s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 358.67699549460957 на 1.1491278209011284.
# [ИНФО][CONTROL] новое направление 1 (было 358)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.84936s N, 30 20m 13.9762s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 1.1491278209011284 на 3.647122810125097.
# [ИНФО][CONTROL] новое направление 3 (было 1)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.85185s N, 30 20m 13.9407s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 3.647122810125097 на 6.161768446712699.
# [ИНФО][CONTROL] новое направление 6 (было 3)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.85434s N, 30 20m 13.9053s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 6.161768446712699 на 8.683472951882038.
# [ИНФО][CONTROL] новое направление 8 (было 6)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.87229s N, 30 20m 13.9045s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 8.683472951882038 на 9.142267923831469.
# [ИНФО][CONTROL] новое направление 9 (было 8)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.89024s N, 30 20m 13.9052s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 9.142267923831469 на 9.527156863441746.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.90815s N, 30 20m 13.9075s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 9.527156863441746 на 9.82525890534788.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.926s N, 30 20m 13.9113s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 9.82525890534788 на 10.021446498834564.
# [ИНФО][CONTROL] новое направление 10 (было 9)
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.94374s N, 30 20m 13.9167s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 10.021446498834564 на 10.097788020960365.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.96147s N, 30 20m 13.9224s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 10.097788020960365 на 10.155862886527018.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.97917s N, 30 20m 13.9283s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 10.155862886527018 на 10.196876990512749.
# [ИНФО][SAFETY] текущие координаты: 59 56m 2.99686s N, 30 20m 13.9344s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 10.196876990512749 на 10.223239341570547.
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.01454s N, 30 20m 13.9407s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 10.223239341570547 на 10.239163731306178.
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.03221s N, 30 20m 13.9469s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 10.239163731306178 на 10.251598160107164.
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.04988s N, 30 20m 13.9532s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 10.251598160107164 на 10.26615537607762.
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.06755s N, 30 20m 13.9595s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 10.26615537607762 на 10.274196269984884.
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.08522s N, 30 20m 13.9659s E
# [ОШИБКА][SAFETY] произошло отклонение от маршрута. Произведена корректировка 10.274196269984884 на 10.281183031830267.
# [ИНФО][SAFETY] маршрут пройден
# [ОШИБКА][SAFETY] превышен лимит скорости на текущем участке. (20/0.0). Ограничиваем до 0.0
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.10289s N, 30 20m 13.9722s E
# [ОШИБКА][SAFETY] ошибка обработки команд: 'NoneType' object has no attribute 'longitude'
# [ИНФО][CONTROL] маршрут пройден, текущее время 17:57:03.151891
# [ИНФО][CONTROL] новая скорость 0.0 (была 20)
# [ИНФО][CONTROL] новое направление 0 (было 10)
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 3.12055s N, 30 20m 13.9786s E
# [ОШИБКА][SAFETY] ошибка обработки команд: 'NoneType' object has no attribute 'longitude'
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# На этом модуль 3 завершён!
#
# Если у вас всё получилось, то вы создали защищённую автономную машинку - ещё уже не так-то просто использовать для нанесения критического ущерба людям и имуществу, потому что самые критические режимы проверяются вашим Ограничителем, а если вы ещё и внедрили Монитор Безопасности, то теперь злоумышленнику гораздо сложнее атаковать внутренние блоки, даже если он смог проникнуть в какую-то бортовую систему или внедрить вредоносный код.
#
# Осталось проверить эффективность получившейся защиты на полной трассе - в этом и заключается модуль 4 задания, для перехода к которому нужно открыть блокнот с именем cyberimmunity--autonomous-car-m4. Успеха!
